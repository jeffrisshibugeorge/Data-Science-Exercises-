# %% [markdown]
# # EDA MID EXAM

# %% [markdown]
# ---------------------------

# %% [markdown]
# # SECTION A: 8 MARKS

# %% [markdown]
# --------------

# %% [markdown]
# ### 1. What is the difference between one hot encoding and label encoding? (8 MARKS)

# %%
# Label encoding refers to converting the labels into numeric form .

# %%
# One hot encodings refers to splitting the columns which contains numerical categorical data to many columns
# depeneding on the number of categories present in that column.

# %% [markdown]
# --------------------
#
#
# # SECTION B: 17 MARKS
#
#
#
# --------------------

# %% [markdown]
# -------------

# %% [markdown]
# ### Data Set Information:

# %% [markdown]
# * Year
#
# * TSU
#
# * EQ
#
# * Name
#
# * Elevation
#
# * Type
#
# * Status
#
# * Time
#
# * VEI
#
# * Agent
#
# * DEATHS
#
# * DEATHS_DESCRIPTION
#
# * MISSING
#
# * MISSING_DESCRIPTION
#
# * INJURIES
#
# * INJURIES_DESCRIPTION
#
# * DAMAGE_MILLIONS_DOLLARS
#
# * DAMAGE_DESCRIPTION
#
# * HOUSES_DESTROYED
#
# * HOUSES_DESTROYED_DESCRIPTION
#
# * TOTAL_DEATHS
#
# * TOTAL_DEATHS_DESCRIPTION
#
# * TOTAL_MISSING
#
# * TOTAL_MISSING_DESCRIPTION
#
# * TOTAL_INJURIES
#
# * TOTAL_INJURIES_DESCRIPTION
#
# * TOTAL_DAMAGE_MILLIONS_DOLLARS
#
# * TOTAL_DAMAGE_DESCRIPTION
#
# * TOTAL_HOUSES_DESTROYED
#
# * TOTAL_HOUSES_DESTROYED_DESCRIPTION
#
# * Latitude
#
# * Longitude
#
# * Country

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder()

# %%
df = pd.read_csv('data_set.csv', encoding = 'unicode_escape')

# %% [markdown]
# import pandas as pd
#
# import csv
#
# with open("data_set.csv","r")as file:
#
# reader=csv.reader(file) df=pd.read_csv("data_set.csv")
#
# df.head()

# %% [markdown]
# ### 2. Load the dataset and answer the below questions
#
#
#  a. Considering 'Type' as the dependent variable, display the different categories present under the variable 'Type' (4 MARK)
#
#  b. Find the top 3 countries which were worst affected by Volcanos based on the average damage in Dollars (6 MARKS)
#
#  c. Find the countries in which there were more number of missing people due to volcano and also mention the type of the volcano which caused it. (3 MARKS)"
#
#  d. Compare the 'Country' and 'Status' variable and provide inferences about the volcanic eruptions. (4 MARKS)

# %%
df.head()
# Out:
#        Year  TSU   EQ                    Name  Elevation             Type  \
# 0  Jan 2010  NaN  NaN              Tungurahua       5023    Stratovolcano
# 1  Mar 2010  NaN  NaN        Eyjafjallajokull       1666    Stratovolcano
# 2  May 2010  NaN  NaN                  Pacaya       2552  Complex volcano
# 3  May 2010  TSU   EQ                 Sarigan        538    Stratovolcano
# 4  Aug 2010  NaN  NaN  Karangetang [Api Siau]       1784    Stratovolcano
#
#        Status Time  VEI Agent  ...  TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  \
# 0  Historical   D1  3.0   NaN  ...                        NaN             NaN
# 1  Historical   D1  2.0   NaN  ...                        NaN             NaN
# 2  Historical   D1  1.0     T  ...                        1.0             NaN
# 3    Holocene    U  NaN   NaN  ...                        NaN             NaN
# 4  Historical   D1  3.0   NaN  ...                        NaN             5.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 33 columns):
# Year                                  63 non-null object
# TSU                                   2 non-null object
# EQ                                    1 non-null object
# Name                                  63 non-null object
# Elevation                             63 non-null int64
# Type                                  63 non-null object
# Status                                63 non-null object
# Time                                  63 non-null object
# VEI                                   19 non-null float64
# Agent                                 23 non-null object
# DEATHS                                29 non-null float64
# DEATHS_DESCRIPTION                    29 non-null float64
# MISSING                               2 non-null float64
# MISSING_DESCRIPTION                   2 non-null float64
# INJURIES                              18 non-null float64
# ...

# %%
#a. Considering 'Type' as the dependent variable, display the different categories present under the variable 'Type

# %%
print(df['Type'].unique())
# Out:
# ['Stratovolcano' 'Complex volcano' 'Shield volcano' 'Subglacial volcano'
#  'Lava dome' 'Caldera']

# %%
#b. Find the top 3 countries which were worst affected by Volcanos based on the average damage in Dollars

# %%
df.head()
# Out:
#        Year  TSU   EQ                    Name  Elevation             Type  \
# 0  Jan 2010  NaN  NaN              Tungurahua       5023    Stratovolcano
# 1  Mar 2010  NaN  NaN        Eyjafjallajokull       1666    Stratovolcano
# 2  May 2010  NaN  NaN                  Pacaya       2552  Complex volcano
# 3  May 2010  TSU   EQ                 Sarigan        538    Stratovolcano
# 4  Aug 2010  NaN  NaN  Karangetang [Api Siau]       1784    Stratovolcano
#
#        Status Time  VEI Agent  ...  TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  \
# 0  Historical   D1  3.0   NaN  ...                        NaN             NaN
# 1  Historical   D1  2.0   NaN  ...                        NaN             NaN
# 2  Historical   D1  1.0     T  ...                        1.0             NaN
# 3    Holocene    U  NaN   NaN  ...                        NaN             NaN
# 4  Historical   D1  3.0   NaN  ...                        NaN             5.0
#
# ...

# %%
df1 = df.groupby('Country')['TOTAL_DAMAGE_MILLIONS_DOLLARS'].mean()
df1.nlargest()
# Out:
# Country
# Indonesia        350.00
# United States     14.50
# Philippines        3.72
# Name: TOTAL_DAMAGE_MILLIONS_DOLLARS, dtype: float64

# %%
#c. Find the countries in which there were more number of missing people due to volcano and also mention the type of
#   the volcano which caused it.

# %%
df.head()

# TOTAL_MISSING_DESCRIPTION , Type
# Out:
#        Year  TSU   EQ                    Name  Elevation             Type  \
# 0  Jan 2010  NaN  NaN              Tungurahua       5023    Stratovolcano
# 1  Mar 2010  NaN  NaN        Eyjafjallajokull       1666    Stratovolcano
# 2  May 2010  NaN  NaN                  Pacaya       2552  Complex volcano
# 3  May 2010  TSU   EQ                 Sarigan        538    Stratovolcano
# 4  Aug 2010  NaN  NaN  Karangetang [Api Siau]       1784    Stratovolcano
#
#        Status Time  VEI Agent  ...  TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  \
# 0  Historical   D1  3.0   NaN  ...                        NaN             NaN
# 1  Historical   D1  2.0   NaN  ...                        NaN             NaN
# 2  Historical   D1  1.0     T  ...                        1.0             NaN
# 3    Holocene    U  NaN   NaN  ...                        NaN             NaN
# 4  Historical   D1  3.0   NaN  ...                        NaN             5.0
#
# ...

# %%
df2 = df.groupby('Country')['TOTAL_MISSING_DESCRIPTION']
df2.nlargest()
# Out:
# Country
# Guatemala  2     1.0
# Indonesia  45    1.0
# Name: TOTAL_MISSING_DESCRIPTION, dtype: float64

# %%
#d. Compare the 'Country' and 'Status' variable and provide inferences about the volcanic eruptions

# %% [markdown]
# ---------------
#
# # SECTION C: 25 MARKS
#
#
# -----------------

# %% [markdown]
# ### 3. Using the above dataset answer the below questions.
#
#
#
#  a. Calculate the missing percentage of null values present in the dataset (5 MARKS)
#
#  b. Display a bar plot for the list of columns having NA values more than 75% (5 MARKS)
#
#  c. Fill the below variables with 0 (5 MARK)
#
#  'DEATHS','MISSING','INJURIES','DAMAGE_MILLIONS_DOLLARS',
#  'HOUSES_DESTROYED','TOTAL_DEATHS','TOTAL_MISSING','TOTAL_INJURIES',
#  'TOTAL_DAMAGE_MILLIONS_DOLLARS','TOTAL_HOUSES_DESTROYED'
#
#  d. After imputation, again check for the missing percentage of null values present in the dataset, provide the inference (5 MARK)
#
#  e. Drop the columns which contain more than 50% of null values, name the new data frame as data_new (5 MARKS)"

# %%
#a. Calculate the missing percentage of null values present in the dataset

# %%
(df.isnull().sum())/len(df)
# Out:
# Year                                  0.000000
# TSU                                   0.968254
# EQ                                    0.984127
# Name                                  0.000000
# Elevation                             0.000000
# Type                                  0.000000
# Status                                0.000000
# Time                                  0.000000
# VEI                                   0.698413
# Agent                                 0.634921
# DEATHS                                0.539683
# DEATHS_DESCRIPTION                    0.539683
# MISSING                               0.968254
# MISSING_DESCRIPTION                   0.968254
# INJURIES                              0.714286
# INJURIES_DESCRIPTION                  0.666667
# DAMAGE_MILLIONS_DOLLARS               0.936508
# DAMAGE_DESCRIPTION                    0.349206
# HOUSES_DESTROYED                      0.888889
# HOUSES_DESTROYED_DESCRIPTION          0.746032
# ...

# %%
#b. Display a bar plot for the list of columns having NA values more than 75%

# %%
plt.figure(figsize=(18,7))
plt.bar(df(thresh=df.shape[0]*0.75,how='all',axis=1).value_counts().head().index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-94a37499666d> in <module>
#       1 plt.figure(figsize=(18,7))
# ----> 2 plt.bar(df(thresh=df.shape[0]*0.75,how='all',axis=1).value_counts().head().index)
#
# TypeError: 'DataFrame' object is not callable

# %%
#c. Fill the below variables with 0
#  'DEATHS','MISSING','INJURIES','DAMAGE_MILLIONS_DOLLARS',
# 'HOUSES_DESTROYED','TOTAL_DEATHS','TOTAL_MISSING','TOTAL_INJURIES',
# 'TOTAL_DAMAGE_MILLIONS_DOLLARS','TOTAL_HOUSES_DESTROYED'

# %%
df['DEATHS'] = 0
df['MISSING'] = 0 
df['INJURIES'] = 0
df['DAMAGE_MILLIONS_DOLLARS'] = 0 
df['HOUSES_DESTROYED'] = 0
df['TOTAL_DEATHS'] = 0 
df['TOTAL_MISSING'] = 0 
df['TOTAL_INJURIES'] = 0
df['TOTAL_DAMAGE_MILLIONS_DOLLARS'] = 0
df['TOTAL_HOUSES_DESTROYED'] = 0

# %%
df['DEATHS'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: DEATHS, dtype: int64

# %%
#d. After imputation, again check for the missing percentage of null values present in the dataset, provide the inference

# %%
(df.isnull().sum())/len(df)
# Out:
# Year                                  0.000000
# TSU                                   0.968254
# EQ                                    0.984127
# Name                                  0.000000
# Elevation                             0.000000
# Type                                  0.000000
# Status                                0.000000
# Time                                  0.000000
# VEI                                   0.698413
# Agent                                 0.634921
# DEATHS                                0.000000
# DEATHS_DESCRIPTION                    0.539683
# MISSING                               0.000000
# MISSING_DESCRIPTION                   0.968254
# INJURIES                              0.000000
# INJURIES_DESCRIPTION                  0.666667
# DAMAGE_MILLIONS_DOLLARS               0.000000
# DAMAGE_DESCRIPTION                    0.349206
# HOUSES_DESTROYED                      0.000000
# HOUSES_DESTROYED_DESCRIPTION          0.746032
# ...

# %%
# after imputation the values percentages of the variables are 0.

# %%
#e. Drop the columns which contain more than 50% of null values, name the new data frame as data_new

# %%
df = df.replace([0,' ','NULL'],np.nan)

# %%
data_new = df.dropna(thresh=df.shape[0]*0.5,how='all',axis=1)

# %%
data_new.head()
# Out:
#        Year                    Name  Elevation             Type      Status  \
# 0  Jan 2010              Tungurahua       5023    Stratovolcano  Historical
# 1  Mar 2010        Eyjafjallajokull       1666    Stratovolcano  Historical
# 2  May 2010                  Pacaya       2552  Complex volcano  Historical
# 3  May 2010                 Sarigan        538    Stratovolcano    Holocene
# 4  Aug 2010  Karangetang [Api Siau]       1784    Stratovolcano  Historical
#
#   Time  DAMAGE_DESCRIPTION  TOTAL_DAMAGE_DESCRIPTION  Latitude  Longitude  \
# 0   D1                 1.0                       1.0    -1.467    -78.442
# 1   D1                 NaN                       NaN    63.630    -19.620
# 2   D1                 1.0                       1.0    14.381    -90.601
# 3    U                 NaN                       NaN    16.708    145.780
# 4   D1                 NaN                       NaN     2.780    125.480
#
#          Country
# 0        Ecuador
# 1        Iceland
# ...
