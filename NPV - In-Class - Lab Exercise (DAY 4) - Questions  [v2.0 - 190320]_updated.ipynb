# %%
<table align="left" width=100%>
    <tr>
        <td width="10%">
            <img src="in_class.png">
        </td>
        <td>
            <div align="center">
                <font color="#21618C" size=8px>
                  <b> Inclass - Lab <br> (Day 4) </b>
                </font>
            </div>
        </td>
    </tr>
</table>
# Out:
#   File "<ipython-input-1-eac1051b15ff>", line 1
#     <table align="left" width=100%>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##  Table of Content
#
# 1. **[Plots using Library Matplotlib ](#matplotlib)**
# 2. **[Plots using Library Seaborn ](#seaborn)**

# %% [markdown]
# ### Let us import the required libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='matplotlib'></a>
# ## 1. Plots using Library Matplotlib

# %% [markdown]
# ### a. Scatter Plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Plot a scatter plot for the following data. Also add title and axis names</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
#             medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)

sb.scatterplot(x=bmi,y=medical_claim)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Write a code to get the following output </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="cos_curve.png" width = '500' >

# %% [markdown]
# ### b. Barplots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 3. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Year</th>
#   <th>Import</th>
#   <th>Export</th>
#   </tr>
#   <tr>
#   <td>2001</td>
#   <td>54.4</td>
#   <td>42.5 </td>
#   </tr>
#   <tr>
#   <td>2002</td>
#   <td>53.8</td>
#   <td>44.5</td>
#   </tr>
#   <tr>
#   <td>2003</td>
#   <td>61.6</td>
#   <td>48.3</td>
#   </tr>
#   <tr>
#   <td>2004</td>
#   <td>74.15</td>
#   <td>57.24</td>
#   </tr>
#   <tr>
#   <td>2005</td>
#   <td>89.33</td>
#   <td>69.18</td>
#   </tr>
# </table>

# %%
year = pd.DataFrame({'year': [2001,2002,2003,2004,2005],'Import': [54.4,53.8,61.6,74.15,89.33],'Export': [42.5,44.5,48.3,57.24,69.18]})
year = year.set_index('year')

# %%
year.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### c. Pie plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 4. Plot a pie chart for the following data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         prices = [50, 25, 50, 20]
#         labels = ['Apple', 'Orange','Banana', 'Mango']

# %%
prices = [50, 25, 50, 20]
labels = ['Apple', 'Orange','Banana', 'Mango']

# %%
data = pd.DataFrame({'prices': [50,25,50,20],'labels': ['Apple','Orange','Banana','Mango']})

# %%
data
# Out:
#    prices  labels
# 0      50   Apple
# 1      25  Orange
# 2      50  Banana
# 3      20   Mango

# %%
plt.pie(data['prices'],labels=data['labels'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 5. Following is the information release after the Indian budget is declared. Plot a pie chart for it
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Income Form </th>
#   <th>Amount (in paise)</th>
#   </tr>
#   <tr>
#   <td>Corporation Tax</td>
#   <td>21</td>
#   </tr>
#   <tr>
#   <td>Income Tax</td>
#   <td>16</td>
#   </tr>
#   <tr>
#   <td>Customs</td>
#   <td>4</td>
#   </tr>
#   <tr>
#   <td>Union Excise Duties</td>
#   <td>8</td>
# </tr>
#   <tr>
#   <td>GST & Other Taxes</td>
#   <td>19</td>
# </tr>
# <tr>
#   <td>Non-Tax Revenue</td>
#   <td>9</td>
#   </tr>
#   <tr>
#   <td>Non-Debt Capital Receipts</td>
#   <td>3</td>
# </tr>
#   <tr>
#   <td>Borrowings and Other Liabilities</td>
#   <td>20</td>
#   </tr>
# </table>

# %%
ind_bug = pd.DataFrame({'Income Form': ['Corportation Tax','Income Tax','Customs','Union Excise Duties','GST & Other Taxes','Non-Tax Revenue','Non-Debt Capital Receipts','Borrowings and Other Liabilities'], 'Amount':[21,16,4,8,19,9,3,20]})

# %%
plt.pie(ind_bug['Amount'],labels=ind_bug['Income Form']);

# %% [markdown]
# ### d. Line plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 6. Create a tuple of numbers 12, 34, 54, 45, 45, 45, 23, 23, 54 and plot a simple line plot
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
a = np.array([12,34,54,45,45,45,23,23,54])

# %%
a
# Out:
# array([12, 34, 54, 45, 45, 45, 23, 23, 54])

# %%
plt.plot(a);

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 7. Import the 'Returns.csv'. Plot a multiple line plot for the returns of each company
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data=pd.read_csv('Returns.csv')
data=data.set_index('Day')
data.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Day'>

# %% [markdown]
# <a id='seaborn'></a>
# ## 2. Plots using Library Seaborn

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 8. Plot a  strip plot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
a=sb.load_dataset('iris')
sb.stripplot(x=a['species'],y=a['sepal_length'])
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 9. Import the dataset age_height.csv. Plot a heat map for the correlation matrix
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=pd.read_csv('age_height.csv')
x
sb.heatmap(x)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 10. Using the following data, plot a scatter plot with  the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
#             y = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
y = (145, 456, 764, 234, 156, 786, 345, 455, 675)

num1 = np.array(x)
num2 = np.array(y)

sb.scatterplot(x=num1,y=num2);

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 11. Using the 'diamonds' data available in the library seaborn, consider the price for the type of cut. Display the data using the following plots:
#                         <ol>
#                             <li> Multiple boxplot</li>
#                             <li> Violin Plot </li>
#                             <li> Boxen Plot </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
diam=sb.load_dataset('diamonds')
sb.boxplot(x=diam['cut'],y=diam['price'])
plt.show()

# %%
sb.violinplot(x=diam['cut'],y=diam['price'])
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sb.boxenplot(x=diam['cut'],y=diam['price'])
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 12. Generate random number form normal distribution, plot the following:
#                         <ol>
#                             <li> Histogram</li>
#                             <li> Histogram with frequency curve </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
np.random.seed(15)
b=np.random.randn(50)
a1=pd.Series(b)
sb.distplot(a1,kde=False)

sb.distplot(a1)
plt.show()
# Out:
# C:\Users\Jeffris\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(a1)
plt.show()
# Out:
# C:\Users\Jeffris\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
